# %% [markdown]
# # Task 1

# %% [markdown]
# # Import Labrary

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\absub\\Documents\\Salary Data.csv")
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
#Getting first five dataset
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
#Getting last five Dataset
df.tail()
# Out:
#       Age  Gender Education Level                      Job Title  \
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0

# %%
#Looking at the number of row and column in the Dataset
df.shape
# Out:
# (375, 6)

# %%
#Getting Statistical information of dataset
df.describe()
# Out:
#               Age  Years of Experience         Salary
# count  373.000000           373.000000     373.000000
# mean    37.431635            10.030831  100577.345845
# std      7.069073             6.557007   48240.013482
# min     23.000000             0.000000     350.000000
# 25%     31.000000             4.000000   55000.000000
# 50%     36.000000             9.000000   95000.000000
# 75%     44.000000            15.000000  140000.000000
# max     53.000000            25.000000  250000.000000

# %%
#looking at the column information of given dataset
df.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
list(df['Gender'].value_counts().keys())
# Out:
# ['Male', 'Female']

# %%
df['Gender'].value_counts()
# Out:
# Male      194
# Female    179
# Name: Gender, dtype: int64

# %%
#Plot Bar chart 
plt.xlabel("Gender")
plt.ylabel("frequency of Gender")
plt.title("Bar Chart")
plt.bar(list(df['Gender'].value_counts().keys()),list(df['Gender'].value_counts()),color=['g','r'])
plt.show()

# %%
df['Age'].value_counts()
# Out:
# 33.0    24
# 29.0    23
# 35.0    22
# 31.0    21
# 44.0    21
# 36.0    20
# 34.0    17
# 45.0    17
# 38.0    15
# 30.0    15
# 47.0    15
# 40.0    13
# 28.0    13
# 43.0    12
# 37.0    12
# 41.0    12
# 32.0    12
# 39.0    12
# 42.0    11
# 46.0    10
# 27.0     9
# 48.0     9
# 50.0     8
# 49.0     8
# 26.0     7
# 51.0     5
# 25.0     4
# 52.0     3
# 24.0     1
# 23.0     1
# 53.0     1
# Name: Age, dtype: int64

# %%
list(df['Age'].value_counts().keys())
# Out:
# [33.0,
#  29.0,
#  35.0,
#  31.0,
#  44.0,
#  36.0,
#  34.0,
#  45.0,
#  38.0,
#  30.0,
#  47.0,
#  40.0,
#  28.0,
#  43.0,
#  37.0,
#  41.0,
#  32.0,
#  39.0,
#  42.0,
#  46.0,
#  27.0,
#  48.0,
#  50.0,
#  49.0,
#  26.0,
#  51.0,
#  25.0,
#  52.0,
#  24.0,
#  23.0,
#  53.0]

# %%
#Plot Bar Chart
plt.xlabel("Age")
plt.ylabel("Frequency of Age")
plt.title("Bar Chart")
plt.bar(list(df['Age'].value_counts().keys()),list(df['Age'].value_counts()))
plt.show()

# %%
list(df['Age'])
# Out:
# [32.0,
#  28.0,
#  45.0,
#  36.0,
#  52.0,
#  29.0,
#  42.0,
#  31.0,
#  26.0,
#  38.0,
#  29.0,
#  48.0,
#  35.0,
#  40.0,
#  27.0,
#  44.0,
#  33.0,
#  39.0,
#  25.0,
#  51.0,
#  34.0,
#  47.0,
#  30.0,
#  36.0,
#  41.0,
#  28.0,
#  37.0,
#  24.0,
#  43.0,
#  33.0,
#  50.0,
#  31.0,
#  29.0,
#  39.0,
#  46.0,
#  27.0,
#  35.0,
#  42.0,
#  26.0,
#  49.0,
#  34.0,
#  48.0,
#  30.0,
#  36.0,
#  41.0,
#  28.0,
#  32.0,
#  45.0,
#  38.0,
#  25.0,
#  51.0,
#  33.0,
#  40.0,
#  47.0,
#  29.0,
#  36.0,
#  27.0,
#  43.0,
#  30.0,
#  35.0,
#  51.0,
#  29.0,
#  40.0,
#  47.0,
#  26.0,
#  38.0,
#  46.0,
#  31.0,
#  34.0,
#  49.0,
#  33.0,
#  39.0,
#  45.0,
#  28.0,
#  42.0,
#  37.0,
#  50.0,
#  32.0,
#  48.0,
#  30.0,
#  36.0,
#  41.0,
#  25.0,
#  52.0,
#  29.0,
#  34.0,
#  27.0,
#  40.0,
#  46.0,
#  31.0,
#  36.0,
#  29.0,
#  43.0,
#  52.0,
#  33.0,
#  39.0,
#  47.0,
#  26.0,
#  38.0,
#  45.0,
#  31.0,
#  35.0,
#  49.0,
#  33.0,
#  39.0,
#  44.0,
#  30.0,
#  36.0,
#  41.0,
#  28.0,
#  42.0,
# ...

# %%
#Plot Histogram Chart
plt.xlabel("Frequency of Age")
plt.title("Histogram Chart")
plt.hist(list(df['Age']))
plt.show()

# %%
#Plot Histogram Chart
plt.xlabel("Frequecy of Gender")
plt.title("Histogram Chart")
plt.hist(list(df['Gender'].value_counts()))
plt.show()
